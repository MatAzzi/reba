# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://cdn.buenosaires.gob.ar/datosabiertos/datasets/ministerio-de-economia-y-finanzas/buenos-aires-compras/bac_anual.csv', low_memory=False) # col 23, 24, 25, 109, 110, 111, 112 vacias
# df.head()

# %%
i = 0
for col in df.columns:
    print(str(i) + ' - ' + col)
    i+=1
# Out:
# 0 - ocid
# 1 - id
# 2 - date
# 3 - initiationType
# 4 - tag
# 5 - tender/id
# 6 - tender/title
# 7 - tender/description
# 8 - tender/status
# 9 - tender/procuringEntity/id
# 10 - tender/value/currency
# 11 - tender/value/amount
# 12 - tender/procuringEntity/name
# 13 - tender/procurementMethod
# 14 - tender/procurementMethodDetails
# 15 - tender/mainProcurementCategory
# 16 - tender/additionalProcurementCategories
# 17 - tender/tenderPeriod/startDate
# 18 - tender/tenderPeriod/endDate
# 19 - tender/tenderPeriod/durationInDays
# 20 - tender/enquiryPeriod/startDate
# 21 - tender/enquiryPeriod/endDate
# 22 - tender/enquiryPeriod/durationInDays
# 23 - tender/techniques/frameworkAgreement/method
# 24 - tender/techniques/frameworkAgreement/period/startDate
# 25 - tender/techniques/frameworkAgreement/period/endDate
# 26 - tender/techniques/frameworkAgreement/period/durationInDays
# 27 - tender/techniques/frameworkAgreement/value/amount
# 28 - tender/techniques/frameworkAgreement/value/currency
# 29 - tender/techniques/hasFrameworkAgreement
# 30 - tender/competitive
# 31 - language
# 32 - tender/items/0/id
# 33 - tender/items/0/description
# 34 - tender/items/0/quantity
# 35 - tender/items/0/unit/name
# 36 - tender/items/0/unit/scheme
# 37 - tender/items/0/classification/scheme
# 38 - tender/items/0/classification/id
# 39 - tender/items/0/unit/value/amount
# 40 - tender/items/0/unit/value/currency
# 41 - tender/documents/0/id
# 42 - tender/documents/0/documentType
# 43 - tender/documents/0/url
# 44 - tender/documents/0/datePublished
# 45 - tender/documents/0/language
# 46 - awards/0/id
# 47 - awards/0/title
# 48 - awards/0/description
# 49 - awards/0/status
# 50 - awards/0/date
# 51 - awards/0/value/amount
# 52 - awards/0/value/currency
# 53 - awards/0/contractPeriod/startDate
# 54 - awards/0/contractPeriod/endDate
# 55 - awards/0/contractPeriod/durationInDays
# 56 - awards/0/items/0/id
# 57 - awards/0/items/0/description
# 58 - awards/0/items/0/classification/scheme
# 59 - awards/0/items/0/classification/id
# 60 - awards/0/items/0/quantity
# 61 - awards/0/items/0/unit/scheme
# 62 - awards/0/items/0/unit/name
# 63 - awards/0/items/0/unit/value/amount
# 64 - awards/0/items/0/unit/value/currency
# 65 - awards/0/documents/0/id
# 66 - awards/0/documents/0/documentType
# 67 - awards/0/documents/0/url
# 68 - awards/0/documents/0/datePublished
# 69 - awards/0/documents/0/language
# 70 - awards/0/suppliers/0/name
# 71 - awards/0/suppliers/0/id
# 72 - contracts/0/id
# 73 - contracts/0/awardID
# 74 - contracts/0/title
# 75 - contracts/0/description
# 76 - contracts/0/status
# 77 - contracts/0/period/startDate
# 78 - contracts/0/period/endDate
# 79 - contracts/0/period/durationInDays
# 80 - contracts/0/value/amount
# 81 - contracts/0/value/currency
# 82 - contracts/0/dateSigned
# 83 - contracts/0/items/0/id
# 84 - contracts/0/items/0/description
# 85 - contracts/0/items/0/classification/scheme
# 86 - contracts/0/items/0/classification/id
# 87 - contracts/0/items/0/quantity
# 88 - contracts/0/items/0/unit/scheme
# 89 - contracts/0/items/0/unit/name
# 90 - contracts/0/items/0/unit/value/amount
# 91 - contracts/0/items/0/unit/value/currency
# 92 - contracts/0/signatories/0/name
# 93 - contracts/0/signatories/0/id
# 94 - parties/0/name
# 95 - parties/0/id
# 96 - parties/0/identifier/scheme
# 97 - parties/0/identifier/id
# 98 - parties/0/identifier/legalName
# 99 - parties/0/roles
# 100 - parties/0/address/streetAddress
# 101 - parties/0/address/locality
# 102 - parties/0/address/postalCode
# 103 - parties/0/address/countryName
# 104 - parties/0/contactPoint/name
# 105 - parties/0/contactPoint/email
# 106 - parties/0/contactPoint/telephone
# 107 - parties/0/contactPoint/url
# 108 - relatedProcesses/id
# 109 - relatedProcesses/relationship
# 110 - relatedProcesses/title
# 111 - relatedProcesses/scheme
# 112 - relatedProcesses/identifier

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65378 entries, 0 to 65377
# Columns: 113 entries, ocid to relatedProcesses/identifier
# dtypes: bool(2), float64(15), int64(2), object(94)
# memory usage: 55.5+ MB

# %%
df.describe()
# Out:
#        tender/value/amount  tender/tenderPeriod/durationInDays  \
# count         6.537800e+04                        65378.000000
# mean          2.965012e+07                           14.759460
# std           8.755798e+08                           15.832328
# min           0.000000e+00                            0.000000
# 25%           0.000000e+00                            5.000000
# 50%           3.105275e+04                            8.000000
# 75%           2.255962e+05                           17.000000
# max           3.561339e+10                          119.000000
#
#        tender/enquiryPeriod/durationInDays  \
# count                         65378.000000
# mean                             12.646058
# std                              14.203103
# min                               0.000000
# 25%                               4.000000
# 50%                               7.000000
# 75%                              14.000000
# max                             116.000000
#
#        tender/techniques/frameworkAgreement/period/durationInDays  \
# count                                          79.000000
# mean                                          197.075949
# std                                           416.270523
# min                                             0.000000
# 25%                                             0.000000
# 50%                                            20.000000
# 75%                                            71.000000
# max                                          1461.000000
#
#        tender/techniques/frameworkAgreement/value/amount  \
# count                                       1.184700e+04
# mean                                        5.680365e+05
# std                                         2.351397e+06
# min                                         1.353600e+02
# 25%                                         3.041480e+04
# 50%                                         1.749990e+05
# 75%                                         3.823705e+05
# max                                         4.399631e+07
#
#        tender/items/0/quantity  tender/items/0/unit/value/amount  \
# count             6.537800e+04                      6.537800e+04
# mean              2.434222e+05                      2.324130e+05
# std               5.536786e+06                      3.537370e+06
# min               1.000000e-01                      0.000000e+00
# 25%               5.000000e+00                      0.000000e+00
# 50%               4.000000e+01                      5.810000e+02
# 75%               2.000000e+02                      1.484952e+04
# max               1.851043e+08                      1.740000e+08
#
#        awards/0/value/amount  awards/0/contractPeriod/durationInDays  \
# count           5.130200e+04                            39305.000000
# mean            2.431158e+06                              237.386236
# std             7.894098e+07                              287.645071
# min             1.000000e-02                                1.000000
# 25%             3.392450e+04                               90.000000
# 50%             1.659600e+05                              184.000000
# 75%             6.986000e+05                              365.000000
# max             1.233016e+10                            11110.000000
#
#        awards/0/items/0/quantity  awards/0/items/0/unit/value/amount  \
# count               5.130200e+04                        5.130200e+04
# mean                1.947926e+04                        2.278666e+05
# std                 4.966813e+05                        2.926096e+06
# min                 7.000000e-02                        1.000000e-02
# 25%                 2.000000e+00                        8.100025e+02
# 50%                 1.000000e+01                        6.971415e+03
# 75%                 1.000000e+02                        7.346080e+04
# max                 4.000000e+07                        2.976201e+08
#
#        contracts/0/period/durationInDays  contracts/0/value/amount  \
# count                       39484.000000              5.130200e+04
# mean                          236.654316              3.186464e+06
# std                           277.386241              5.611503e+07
# min                             0.000000              1.000000e-02
# 25%                            88.000000              2.444100e+04
# 50%                           184.000000              1.276800e+05
# 75%                           365.000000              4.137986e+05
# max                         11110.000000              1.973702e+09
#
#        contracts/0/items/0/quantity  contracts/0/items/0/unit/value/amount  \
# count                  5.130200e+04                           5.130200e+04
# mean                   1.895716e+04                           1.864710e+05
# std                    4.902191e+05                           2.237831e+06
# min                    3.000000e-02                           1.000000e-02
# 25%                    2.000000e+00                           6.728700e+02
# 50%                    1.000000e+01                           5.694000e+03
# 75%                    1.000000e+02                           5.428000e+04
# max                    4.000000e+07                           1.824415e+08
#
#        parties/0/contactPoint/telephone  relatedProcesses/id
# count                      4.478600e+04         14704.000000
# mean                       5.401152e+12         99549.558624
# std                        0.000000e+00         52406.170940
# min                        5.401152e+12         13907.000000
# 25%                        5.401152e+12         32466.750000
# 50%                        5.401152e+12        120394.500000
# 75%                        5.401152e+12        144870.000000
# max                        5.401152e+12        149133.000000

# %%
df.isnull().sum()
# Out:
# ocid                                 0
# id                                   0
# date                                 0
# initiationType                       0
# tag                                  0
#                                  ...
# relatedProcesses/id              50674
# relatedProcesses/relationship    50674
# relatedProcesses/title           50674
# relatedProcesses/scheme          50674
# relatedProcesses/identifier      53531
# Length: 113, dtype: int64

# %%
# recuento de los valores faltantes y calculo del porcentaje de los mismos

valores_faltantes = df.isnull().sum()
valores_totales = df.isnull().count()
porcentaje_faltantes = round(valores_faltantes/valores_totales*100,2)
faltantes_df = pd.DataFrame({'cuenta': valores_faltantes, 'porcentaje': porcentaje_faltantes})
print(faltantes_df)
# Out:
#                                cuenta  porcentaje
# ocid                                0        0.00
# id                                  0        0.00
# date                                0        0.00
# initiationType                      0        0.00
# tag                                 0        0.00
# ...                               ...         ...
# relatedProcesses/id             50674       77.51
# relatedProcesses/relationship   50674       77.51
# relatedProcesses/title          50674       77.51
# relatedProcesses/scheme         50674       77.51
# relatedProcesses/identifier     53531       81.88
#
# [113 rows x 2 columns]

# %%
# Grafico los resultados

barchart = faltantes_df.plot.bar(y='porcentaje', figsize = (30, 10))

for index, porcentaje in enumerate(porcentaje_faltantes):
    barchart.text(index, porcentaje, str(porcentaje)+'%')

# %%
faltantes_df.query('porcentaje>70')
# Out:
#                                                     cuenta  porcentaje
# tender/techniques/frameworkAgreement/method          50674       77.51
# tender/techniques/frameworkAgreement/period/sta...   65299       99.88
# tender/techniques/frameworkAgreement/period/end...   53531       81.88
# tender/techniques/frameworkAgreement/period/dur...   65299       99.88
# tender/techniques/frameworkAgreement/value/amount    53531       81.88
# tender/techniques/frameworkAgreement/value/curr...   53531       81.88
# relatedProcesses/id                                  50674       77.51
# relatedProcesses/relationship                        50674       77.51
# relatedProcesses/title                               50674       77.51
# relatedProcesses/scheme                              50674       77.51
# relatedProcesses/identifier                          53531       81.88

# %%
# elimino las filas duplicadas

# dropeo las primeras dos columnas de identificacion, parecen no tener info solo es un index
df = df.drop(['ocid', 'id'], axis=1, index=None)

# %%
# elimino todos los duplica
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63300 entries, 0 to 65377
# Columns: 111 entries, date to relatedProcesses/identifier
# dtypes: bool(2), float64(15), int64(2), object(92)
# memory usage: 53.2+ MB

# %%
# Veo el tipo de dato por columna

i = 0
for col in df.columns:
    print(str(i) + ' - ' + col + ' - ' + str(df[col].dtype))
    i+=1
# Out:
# 0 - date - object
# 1 - initiationType - object
# 2 - tag - object
# 3 - tender/id - object
# 4 - tender/title - object
# 5 - tender/description - object
# 6 - tender/status - object
# 7 - tender/procuringEntity/id - object
# 8 - tender/value/currency - object
# 9 - tender/value/amount - float64
# 10 - tender/procuringEntity/name - object
# 11 - tender/procurementMethod - object
# 12 - tender/procurementMethodDetails - object
# 13 - tender/mainProcurementCategory - object
# 14 - tender/additionalProcurementCategories - object
# 15 - tender/tenderPeriod/startDate - object
# 16 - tender/tenderPeriod/endDate - object
# 17 - tender/tenderPeriod/durationInDays - int64
# 18 - tender/enquiryPeriod/startDate - object
# 19 - tender/enquiryPeriod/endDate - object
# 20 - tender/enquiryPeriod/durationInDays - int64
# 21 - tender/techniques/frameworkAgreement/method - object
# 22 - tender/techniques/frameworkAgreement/period/startDate - object
# 23 - tender/techniques/frameworkAgreement/period/endDate - object
# 24 - tender/techniques/frameworkAgreement/period/durationInDays - float64
# 25 - tender/techniques/frameworkAgreement/value/amount - float64
# 26 - tender/techniques/frameworkAgreement/value/currency - object
# 27 - tender/techniques/hasFrameworkAgreement - bool
# 28 - tender/competitive - bool
# 29 - language - object
# 30 - tender/items/0/id - object
# 31 - tender/items/0/description - object
# 32 - tender/items/0/quantity - float64
# 33 - tender/items/0/unit/name - object
# 34 - tender/items/0/unit/scheme - object
# 35 - tender/items/0/classification/scheme - object
# 36 - tender/items/0/classification/id - object
# 37 - tender/items/0/unit/value/amount - float64
# 38 - tender/items/0/unit/value/currency - object
# 39 - tender/documents/0/id - object
# 40 - tender/documents/0/documentType - object
# 41 - tender/documents/0/url - object
# 42 - tender/documents/0/datePublished - object
# 43 - tender/documents/0/language - object
# 44 - awards/0/id - object
# 45 - awards/0/title - object
# 46 - awards/0/description - object
# 47 - awards/0/status - object
# 48 - awards/0/date - object
# 49 - awards/0/value/amount - float64
# 50 - awards/0/value/currency - object
# 51 - awards/0/contractPeriod/startDate - object
# 52 - awards/0/contractPeriod/endDate - object
# 53 - awards/0/contractPeriod/durationInDays - float64
# 54 - awards/0/items/0/id - object
# 55 - awards/0/items/0/description - object
# 56 - awards/0/items/0/classification/scheme - object
# 57 - awards/0/items/0/classification/id - object
# 58 - awards/0/items/0/quantity - float64
# 59 - awards/0/items/0/unit/scheme - object
# 60 - awards/0/items/0/unit/name - object
# 61 - awards/0/items/0/unit/value/amount - float64
# 62 - awards/0/items/0/unit/value/currency - object
# 63 - awards/0/documents/0/id - object
# 64 - awards/0/documents/0/documentType - object
# 65 - awards/0/documents/0/url - object
# 66 - awards/0/documents/0/datePublished - object
# 67 - awards/0/documents/0/language - object
# 68 - awards/0/suppliers/0/name - object
# 69 - awards/0/suppliers/0/id - object
# 70 - contracts/0/id - object
# 71 - contracts/0/awardID - object
# 72 - contracts/0/title - object
# 73 - contracts/0/description - object
# 74 - contracts/0/status - object
# 75 - contracts/0/period/startDate - object
# 76 - contracts/0/period/endDate - object
# 77 - contracts/0/period/durationInDays - float64
# 78 - contracts/0/value/amount - float64
# 79 - contracts/0/value/currency - object
# 80 - contracts/0/dateSigned - object
# 81 - contracts/0/items/0/id - object
# 82 - contracts/0/items/0/description - object
# 83 - contracts/0/items/0/classification/scheme - object
# 84 - contracts/0/items/0/classification/id - object
# 85 - contracts/0/items/0/quantity - float64
# 86 - contracts/0/items/0/unit/scheme - object
# 87 - contracts/0/items/0/unit/name - object
# 88 - contracts/0/items/0/unit/value/amount - float64
# 89 - contracts/0/items/0/unit/value/currency - object
# 90 - contracts/0/signatories/0/name - object
# 91 - contracts/0/signatories/0/id - object
# 92 - parties/0/name - object
# 93 - parties/0/id - object
# 94 - parties/0/identifier/scheme - object
# 95 - parties/0/identifier/id - object
# 96 - parties/0/identifier/legalName - object
# 97 - parties/0/roles - object
# 98 - parties/0/address/streetAddress - object
# 99 - parties/0/address/locality - object
# 100 - parties/0/address/postalCode - object
# 101 - parties/0/address/countryName - object
# 102 - parties/0/contactPoint/name - object
# 103 - parties/0/contactPoint/email - object
# 104 - parties/0/contactPoint/telephone - float64
# 105 - parties/0/contactPoint/url - object
# 106 - relatedProcesses/id - float64
# 107 - relatedProcesses/relationship - object
# 108 - relatedProcesses/title - object
# 109 - relatedProcesses/scheme - object
# 110 - relatedProcesses/identifier - object

# %%
# Formato de fechas AAAA/MM/DD

columnas_fechas = ['date', 'tender/tenderPeriod/startDate', 'tender/tenderPeriod/endDate', 'tender/enquiryPeriod/startDate', 'tender/enquiryPeriod/endDate', 
                   'tender/documents/0/datePublished', 'tender/techniques/frameworkAgreement/period/startDate','tender/techniques/frameworkAgreement/period/endDate',
                   'awards/0/date', 'awards/0/documents/0/datePublished','awards/0/contractPeriod/startDate','awards/0/contractPeriod/endDate', 
                   'awards/0/documents/0/datePublished', 'contracts/0/period/startDate', 'contracts/0/period/endDate', 'contracts/0/dateSigned']

for i in columnas_fechas:
    df[i] = pd.to_datetime(df[i], format="%Y/%m/%d")
    df[i] = df[i].dt.strftime('%Y/%m/%d')
    print(i)
# Out:
# date
# tender/tenderPeriod/startDate
# tender/tenderPeriod/endDate
# tender/enquiryPeriod/startDate
# tender/enquiryPeriod/endDate
# tender/documents/0/datePublished
# tender/techniques/frameworkAgreement/period/startDate
# tender/techniques/frameworkAgreement/period/endDate
# awards/0/date
# awards/0/documents/0/datePublished
# awards/0/contractPeriod/startDate
# awards/0/contractPeriod/endDate
# awards/0/documents/0/datePublished
# contracts/0/period/startDate
# contracts/0/period/endDate
# contracts/0/dateSigned

# %%
# divido las columnas segun categorica o numericas

from pandas.core.dtypes.api import is_numeric_dtype, is_string_dtype

num_list = []
cat_list = []

for col in df:
    if is_numeric_dtype(df[col]):
        num_list.append(col)
    elif is_string_dtype(df[col]):
        cat_list.append(col)

# print("Variables numericas: ",num_list)
# print("Variables categoricas: ",cat_list)

# %%
# Veo el contenido de cada columna para determinar si tiene datos de interes o puede ser despreciada
i = 0
col_valorunico = []
for col in cat_list:
    Desc = df[col].describe()
    if Desc['unique'] == 1:
        print('columna: ' + str(i) + ' - ' + str(col))
        print(Desc['unique'])
        print(Desc['top'])
        print('')
        print('')
        col_valorunico.append(col)
    i += 1
# Out:
# columna: 1 - initiationType
# 1
# tender
#
#
# columna: 18 - tender/techniques/frameworkAgreement/method
# 1
# withAndWithoutReopeningCompetition
#
#
# columna: 21 - tender/techniques/frameworkAgreement/value/currency
# 1
# ARS
#
#
# columna: 22 - language
# 1
# es
#
#
# columna: 26 - tender/items/0/unit/scheme
# 1
# x_unidades_medida_bac
#
#
# columna: 27 - tender/items/0/classification/scheme
# 1
# x_catalogo_bienes_servicios_bac
#
#
# columna: 31 - tender/documents/0/documentType
# 1
# tenderNotice
#
#
# columna: 34 - tender/documents/0/language
# 1
# es
#
#
# columna: 38 - awards/0/status
# 1
# active
#
#
# columna: 45 - awards/0/items/0/classification/scheme
# 1
# x_catalogo_bienes_servicios_BAC
#
#
# columna: 47 - awards/0/items/0/unit/scheme
# 1
# x_unidades_medida_bac
#
#
# columna: 51 - awards/0/documents/0/documentType
# 1
# awardNotice
#
#
# columna: 54 - awards/0/documents/0/language
# 1
# es
#
#
# columna: 68 - contracts/0/items/0/classification/scheme
# 1
# x_catalogo_bienes_servicios_BAC
#
#
# columna: 70 - contracts/0/items/0/unit/scheme
# 1
# x_unidades_medida_bac
#
#
# columna: 81 - parties/0/address/streetAddress
# 1
# Rivadavia 524, 1º Piso
#
#
# columna: 82 - parties/0/address/locality
# 1
# Ciudad de Buenos Aires
#
#
# columna: 83 - parties/0/address/postalCode
# 1
# C1002AAQ
#
#
# columna: 84 - parties/0/address/countryName
# 1
# Republica Argentina
#
#
# columna: 85 - parties/0/contactPoint/name
# 1
# Mesa de Ayuda BAC
#
#
# columna: 86 - parties/0/contactPoint/email
# 1
# mesadeayudabac@dguiaf-gcba.gob.ar
#
#
# columna: 87 - parties/0/contactPoint/url
# 1
# https://www.buenosairescompras.gob.ar
#
#
# columna: 88 - relatedProcesses/relationship
# 1
# framework
#
#
# columna: 90 - relatedProcesses/scheme
# 1
# ocid

# %%
# dropeo todas los columnas con valores unicos salvo la 21, que contiene una divisa (ARG) y no todas las divisas son iguales en el resto de las columnas
col_valorunico.remove('tender/techniques/frameworkAgreement/value/currency')

# %%
df = df.drop(col_valorunico, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63300 entries, 0 to 65377
# Data columns (total 88 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   date                                                        63300 non-null  object
#  1   tag                                                         63300 non-null  object
#  2   tender/id                                                   63300 non-null  object
#  3   tender/title                                                63300 non-null  object
#  4   tender/description                                          63300 non-null  object
#  5   tender/status                                               63218 non-null  object
#  6   tender/procuringEntity/id                                   63300 non-null  object
#  7   tender/value/currency                                       63300 non-null  object
#  8   tender/value/amount                                         63300 non-null  float64
#  9   tender/procuringEntity/name                                 63196 non-null  object
#  10  tender/procurementMethod                                    63300 non-null  object
#  11  tender/procurementMethodDetails                             63300 non-null  object
#  12  tender/mainProcurementCategory                              63300 non-null  object
#  13  tender/additionalProcurementCategories                      63300 non-null  object
#  14  tender/tenderPeriod/startDate                               63300 non-null  object
#  15  tender/tenderPeriod/endDate                                 63300 non-null  object
#  16  tender/tenderPeriod/durationInDays                          63300 non-null  int64
#  17  tender/enquiryPeriod/startDate                              63300 non-null  object
#  18  tender/enquiryPeriod/endDate                                63300 non-null  object
#  19  tender/enquiryPeriod/durationInDays                         63300 non-null  int64
#  20  tender/techniques/frameworkAgreement/period/startDate       79 non-null     object
#  21  tender/techniques/frameworkAgreement/period/endDate         11847 non-null  object
#  22  tender/techniques/frameworkAgreement/period/durationInDays  79 non-null     float64
#  23  tender/techniques/frameworkAgreement/value/amount           11847 non-null  float64
#  24  tender/techniques/frameworkAgreement/value/currency         11847 non-null  object
#  25  tender/techniques/hasFrameworkAgreement                     63300 non-null  bool
#  26  tender/competitive                                          63300 non-null  bool
#  27  tender/items/0/id                                           63300 non-null  object
#  28  tender/items/0/description                                  63300 non-null  object
#  29  tender/items/0/quantity                                     63300 non-null  float64
#  30  tender/items/0/unit/name                                    63300 non-null  object
#  31  tender/items/0/classification/id                            63300 non-null  object
#  32  tender/items/0/unit/value/amount                            63300 non-null  float64
#  33  tender/items/0/unit/value/currency                          63300 non-null  object
#  34  tender/documents/0/id                                       63300 non-null  object
#  35  tender/documents/0/url                                      63300 non-null  object
#  36  tender/documents/0/datePublished                            63300 non-null  object
#  37  awards/0/id                                                 50744 non-null  object
#  38  awards/0/title                                              50744 non-null  object
#  39  awards/0/description                                        50744 non-null  object
#  40  awards/0/date                                               50744 non-null  object
#  41  awards/0/value/amount                                       50744 non-null  float64
#  42  awards/0/value/currency                                     41869 non-null  object
#  43  awards/0/contractPeriod/startDate                           38747 non-null  object
#  44  awards/0/contractPeriod/endDate                             50594 non-null  object
#  45  awards/0/contractPeriod/durationInDays                      38747 non-null  float64
#  46  awards/0/items/0/id                                         50744 non-null  object
#  47  awards/0/items/0/description                                50744 non-null  object
#  48  awards/0/items/0/classification/id                          50744 non-null  object
#  49  awards/0/items/0/quantity                                   50744 non-null  float64
#  50  awards/0/items/0/unit/name                                  50744 non-null  object
#  51  awards/0/items/0/unit/value/amount                          50744 non-null  float64
#  52  awards/0/items/0/unit/value/currency                        41869 non-null  object
#  53  awards/0/documents/0/id                                     50744 non-null  object
#  54  awards/0/documents/0/url                                    50744 non-null  object
#  55  awards/0/documents/0/datePublished                          50744 non-null  object
#  56  awards/0/suppliers/0/name                                   50744 non-null  object
#  57  awards/0/suppliers/0/id                                     50716 non-null  object
#  58  contracts/0/id                                              50744 non-null  object
#  59  contracts/0/awardID                                         50744 non-null  object
#  60  contracts/0/title                                           50744 non-null  object
#  61  contracts/0/description                                     50744 non-null  object
#  62  contracts/0/status                                          50744 non-null  object
#  63  contracts/0/period/startDate                                38926 non-null  object
#  64  contracts/0/period/endDate                                  50694 non-null  object
#  65  contracts/0/period/durationInDays                           38926 non-null  float64
#  66  contracts/0/value/amount                                    50744 non-null  float64
#  67  contracts/0/value/currency                                  42486 non-null  object
#  68  contracts/0/dateSigned                                      50744 non-null  object
#  69  contracts/0/items/0/id                                      50744 non-null  object
#  70  contracts/0/items/0/description                             50744 non-null  object
#  71  contracts/0/items/0/classification/id                       50744 non-null  object
#  72  contracts/0/items/0/quantity                                50744 non-null  float64
#  73  contracts/0/items/0/unit/name                               50744 non-null  object
#  74  contracts/0/items/0/unit/value/amount                       50744 non-null  float64
#  75  contracts/0/items/0/unit/value/currency                     50744 non-null  object
#  76  contracts/0/signatories/0/name                              50744 non-null  object
#  77  contracts/0/signatories/0/id                                50700 non-null  object
#  78  parties/0/name                                              62465 non-null  object
#  79  parties/0/id                                                62487 non-null  object
#  80  parties/0/identifier/scheme                                 63300 non-null  object
#  81  parties/0/identifier/id                                     62473 non-null  object
#  82  parties/0/identifier/legalName                              62465 non-null  object
#  83  parties/0/roles                                             63300 non-null  object
#  84  parties/0/contactPoint/telephone                            43019 non-null  float64
#  85  relatedProcesses/id                                         14704 non-null  float64
#  86  relatedProcesses/title                                      14704 non-null  object
#  87  relatedProcesses/identifier                                 11847 non-null  object
# dtypes: bool(2), float64(15), int64(2), object(69)
# memory usage: 42.1+ MB

# %%
# grafico columnas especificas para normalizar

import seaborn as sns 
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (5, 5))
sns.histplot(data=df, x="tender/items/0/unit/name", kde=False, shrink=.8, discrete=True)
# Out:
# <AxesSubplot:xlabel='tender/items/0/unit/name', ylabel='Count'>

# %%
df['tender/items/0/unit/name'] = df['tender/items/0/unit/name'].str.replace('UNIDAD', 'Unidad')
df['tender/items/0/unit/name'] = df['tender/items/0/unit/name'].str.replace('UNIDADES', 'Unidad')
df['tender/items/0/unit/name'] = df['tender/items/0/unit/name'].str.replace('UnidadES', 'Unidad')

# %%
fig, ax = plt.subplots(figsize = (5, 5))
sns.histplot(data=df, x="tender/items/0/unit/name", kde=False, shrink=.8, discrete=True)
# Out:
# <AxesSubplot:xlabel='tender/items/0/unit/name', ylabel='Count'>

# %%
# Cuento el numero de ocurrencias de litro y unidosis

ocurrencia = df.pivot_table(index = ['tender/items/0/unit/name'], aggfunc ='size')
print(ocurrencia)
# Out:
# tender/items/0/unit/name
# LITRO           4
# UNIDOSIS        5
# Unidad      63291
# dtype: int64

# %%
# veo el contenido de estas lineas

a = df['tender/items/0/unit/name']
index = [i for i, e in enumerate(a) if e == 'LITRO']
print(index)

for i in index:
    print(df.iloc[i])
# Out:
# [16921, 16922, 47369, 47370]
# date                                                  2022/05/31
# tag                                        tender;award;contract
# tender/id                                         419-1481-CME22
# tender/title                        ADQUISICIÓN AGUA EMBOTELLADA
# tender/description                      Alimentos para personas-
#                                                 ...
# parties/0/roles                                         supplier
# parties/0/contactPoint/telephone                             NaN
# relatedProcesses/id                                          NaN
# relatedProcesses/title                                       NaN
# relatedProcesses/identifier                                  NaN
# Name: 17984, Length: 88, dtype: object
# date                                                  2022/05/31
# tag                                        tender;award;contract
# tender/id                                         419-1481-CME22
# tender/title                        ADQUISICIÓN AGUA EMBOTELLADA
# tender/description                      Alimentos para personas-
#                                                 ...
# parties/0/roles                            buyer;procuringEntity
# parties/0/contactPoint/telephone                 5401152364800.0
# relatedProcesses/id                                          NaN
# relatedProcesses/title                                       NaN
# relatedProcesses/identifier                                  NaN
# Name: 17985, Length: 88, dtype: object
# date                                                  2022/05/26
# tag                                                       tender
# tender/id                                         623-0294-LPU22
# tender/title                        Adquisición de Agua potable.
# tender/description                      Alimentos para personas-
#                                                 ...
# parties/0/roles                                  procuringEntity
# parties/0/contactPoint/telephone                 5401152364800.0
# relatedProcesses/id                                      55733.0
# relatedProcesses/title              Adquisición de Agua potable.
# relatedProcesses/identifier                                  NaN
# Name: 48583, Length: 88, dtype: object
# date                                                  2022/05/26
# tag                                                       tender
# tender/id                                         623-0294-LPU22
# tender/title                        Adquisición de Agua potable.
# tender/description                      Alimentos para personas-
#                                                 ...
# parties/0/roles                                  procuringEntity
# parties/0/contactPoint/telephone                 5401152364800.0
# relatedProcesses/id                                      55734.0
# relatedProcesses/title              Adquisición de Agua potable.
# relatedProcesses/identifier                                  NaN
# Name: 48584, Length: 88, dtype: object

# %%
# Para visualizar, se deje eliminar antes de commitear

df.to_csv('bac_anuel_clean.csv')

# %%
# resultado

df.info()

# resultando un df con: 
# 63300 lineas, 2077 menos 
# 88 columnas, 25 menos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63300 entries, 0 to 65377
# Data columns (total 88 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   date                                                        63300 non-null  object
#  1   tag                                                         63300 non-null  object
#  2   tender/id                                                   63300 non-null  object
#  3   tender/title                                                63300 non-null  object
#  4   tender/description                                          63300 non-null  object
#  5   tender/status                                               63218 non-null  object
#  6   tender/procuringEntity/id                                   63300 non-null  object
#  7   tender/value/currency                                       63300 non-null  object
#  8   tender/value/amount                                         63300 non-null  float64
#  9   tender/procuringEntity/name                                 63196 non-null  object
#  10  tender/procurementMethod                                    63300 non-null  object
#  11  tender/procurementMethodDetails                             63300 non-null  object
#  12  tender/mainProcurementCategory                              63300 non-null  object
#  13  tender/additionalProcurementCategories                      63300 non-null  object
#  14  tender/tenderPeriod/startDate                               63300 non-null  object
#  15  tender/tenderPeriod/endDate                                 63300 non-null  object
#  16  tender/tenderPeriod/durationInDays                          63300 non-null  int64
#  17  tender/enquiryPeriod/startDate                              63300 non-null  object
#  18  tender/enquiryPeriod/endDate                                63300 non-null  object
#  19  tender/enquiryPeriod/durationInDays                         63300 non-null  int64
#  20  tender/techniques/frameworkAgreement/period/startDate       79 non-null     object
#  21  tender/techniques/frameworkAgreement/period/endDate         11847 non-null  object
#  22  tender/techniques/frameworkAgreement/period/durationInDays  79 non-null     float64
#  23  tender/techniques/frameworkAgreement/value/amount           11847 non-null  float64
#  24  tender/techniques/frameworkAgreement/value/currency         11847 non-null  object
#  25  tender/techniques/hasFrameworkAgreement                     63300 non-null  bool
#  26  tender/competitive                                          63300 non-null  bool
#  27  tender/items/0/id                                           63300 non-null  object
#  28  tender/items/0/description                                  63300 non-null  object
#  29  tender/items/0/quantity                                     63300 non-null  float64
#  30  tender/items/0/unit/name                                    63300 non-null  object
#  31  tender/items/0/classification/id                            63300 non-null  object
#  32  tender/items/0/unit/value/amount                            63300 non-null  float64
#  33  tender/items/0/unit/value/currency                          63300 non-null  object
#  34  tender/documents/0/id                                       63300 non-null  object
#  35  tender/documents/0/url                                      63300 non-null  object
#  36  tender/documents/0/datePublished                            63300 non-null  object
#  37  awards/0/id                                                 50744 non-null  object
#  38  awards/0/title                                              50744 non-null  object
#  39  awards/0/description                                        50744 non-null  object
#  40  awards/0/date                                               50744 non-null  object
#  41  awards/0/value/amount                                       50744 non-null  float64
#  42  awards/0/value/currency                                     41869 non-null  object
#  43  awards/0/contractPeriod/startDate                           38747 non-null  object
#  44  awards/0/contractPeriod/endDate                             50594 non-null  object
#  45  awards/0/contractPeriod/durationInDays                      38747 non-null  float64
#  46  awards/0/items/0/id                                         50744 non-null  object
#  47  awards/0/items/0/description                                50744 non-null  object
#  48  awards/0/items/0/classification/id                          50744 non-null  object
#  49  awards/0/items/0/quantity                                   50744 non-null  float64
#  50  awards/0/items/0/unit/name                                  50744 non-null  object
#  51  awards/0/items/0/unit/value/amount                          50744 non-null  float64
#  52  awards/0/items/0/unit/value/currency                        41869 non-null  object
#  53  awards/0/documents/0/id                                     50744 non-null  object
#  54  awards/0/documents/0/url                                    50744 non-null  object
#  55  awards/0/documents/0/datePublished                          50744 non-null  object
#  56  awards/0/suppliers/0/name                                   50744 non-null  object
#  57  awards/0/suppliers/0/id                                     50716 non-null  object
#  58  contracts/0/id                                              50744 non-null  object
#  59  contracts/0/awardID                                         50744 non-null  object
#  60  contracts/0/title                                           50744 non-null  object
#  61  contracts/0/description                                     50744 non-null  object
#  62  contracts/0/status                                          50744 non-null  object
#  63  contracts/0/period/startDate                                38926 non-null  object
#  64  contracts/0/period/endDate                                  50694 non-null  object
#  65  contracts/0/period/durationInDays                           38926 non-null  float64
#  66  contracts/0/value/amount                                    50744 non-null  float64
#  67  contracts/0/value/currency                                  42486 non-null  object
#  68  contracts/0/dateSigned                                      50744 non-null  object
#  69  contracts/0/items/0/id                                      50744 non-null  object
#  70  contracts/0/items/0/description                             50744 non-null  object
#  71  contracts/0/items/0/classification/id                       50744 non-null  object
#  72  contracts/0/items/0/quantity                                50744 non-null  float64
#  73  contracts/0/items/0/unit/name                               50744 non-null  object
#  74  contracts/0/items/0/unit/value/amount                       50744 non-null  float64
#  75  contracts/0/items/0/unit/value/currency                     50744 non-null  object
#  76  contracts/0/signatories/0/name                              50744 non-null  object
#  77  contracts/0/signatories/0/id                                50700 non-null  object
#  78  parties/0/name                                              62465 non-null  object
#  79  parties/0/id                                                62487 non-null  object
#  80  parties/0/identifier/scheme                                 63300 non-null  object
#  81  parties/0/identifier/id                                     62473 non-null  object
#  82  parties/0/identifier/legalName                              62465 non-null  object
#  83  parties/0/roles                                             63300 non-null  object
#  84  parties/0/contactPoint/telephone                            43019 non-null  float64
#  85  relatedProcesses/id                                         14704 non-null  float64
#  86  relatedProcesses/title                                      14704 non-null  object
#  87  relatedProcesses/identifier                                 11847 non-null  object
# dtypes: bool(2), float64(15), int64(2), object(69)
# memory usage: 42.1+ MB

# %%
# Conviertro a excel 

df.to_excel("bac_anuel_clean.xlsx")

# %%
# ANLISIS

# %%
# status

fig, ax = plt.subplots(figsize = (5, 5))
sns.histplot(data=df, x="tender/status", kde=False, shrink=.8, discrete=True)
# Out:
# <AxesSubplot:xlabel='tender/status', ylabel='Count'>

# %%
# Existe 4 categorias, la mas importante es "complete", ya que reprensenta los montos efectivos

ocurrencia = df.pivot_table(index = ['tender/status'], aggfunc ='size')
print(ocurrencia)
# Out:
# tender/status
# active           4961
# cancelled        2467
# complete        55388
# unsuccessful      402
# dtype: int64

# %%
# Trabajaremos con las licitaciones completas y las activas

complete = df['tender/status'] == 'complete'
complete_df = df[complete]
complete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55388 entries, 23 to 65377
# Data columns (total 88 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   date                                                        55388 non-null  object
#  1   tag                                                         55388 non-null  object
#  2   tender/id                                                   55388 non-null  object
#  3   tender/title                                                55388 non-null  object
#  4   tender/description                                          55388 non-null  object
#  5   tender/status                                               55388 non-null  object
#  6   tender/procuringEntity/id                                   55388 non-null  object
#  7   tender/value/currency                                       55388 non-null  object
#  8   tender/value/amount                                         55388 non-null  float64
#  9   tender/procuringEntity/name                                 55292 non-null  object
#  10  tender/procurementMethod                                    55388 non-null  object
#  11  tender/procurementMethodDetails                             55388 non-null  object
#  12  tender/mainProcurementCategory                              55388 non-null  object
#  13  tender/additionalProcurementCategories                      55388 non-null  object
#  14  tender/tenderPeriod/startDate                               55388 non-null  object
#  15  tender/tenderPeriod/endDate                                 55388 non-null  object
#  16  tender/tenderPeriod/durationInDays                          55388 non-null  int64
#  17  tender/enquiryPeriod/startDate                              55388 non-null  object
#  18  tender/enquiryPeriod/endDate                                55388 non-null  object
#  19  tender/enquiryPeriod/durationInDays                         55388 non-null  int64
#  20  tender/techniques/frameworkAgreement/period/startDate       79 non-null     object
#  21  tender/techniques/frameworkAgreement/period/endDate         11847 non-null  object
#  22  tender/techniques/frameworkAgreement/period/durationInDays  79 non-null     float64
#  23  tender/techniques/frameworkAgreement/value/amount           11847 non-null  float64
#  24  tender/techniques/frameworkAgreement/value/currency         11847 non-null  object
#  25  tender/techniques/hasFrameworkAgreement                     55388 non-null  bool
#  26  tender/competitive                                          55388 non-null  bool
#  27  tender/items/0/id                                           55388 non-null  object
#  28  tender/items/0/description                                  55388 non-null  object
#  29  tender/items/0/quantity                                     55388 non-null  float64
#  30  tender/items/0/unit/name                                    55388 non-null  object
#  31  tender/items/0/classification/id                            55388 non-null  object
#  32  tender/items/0/unit/value/amount                            55388 non-null  float64
#  33  tender/items/0/unit/value/currency                          55388 non-null  object
#  34  tender/documents/0/id                                       55388 non-null  object
#  35  tender/documents/0/url                                      55388 non-null  object
#  36  tender/documents/0/datePublished                            55388 non-null  object
#  37  awards/0/id                                                 50744 non-null  object
#  38  awards/0/title                                              50744 non-null  object
#  39  awards/0/description                                        50744 non-null  object
#  40  awards/0/date                                               50744 non-null  object
#  41  awards/0/value/amount                                       50744 non-null  float64
#  42  awards/0/value/currency                                     41869 non-null  object
#  43  awards/0/contractPeriod/startDate                           38747 non-null  object
#  44  awards/0/contractPeriod/endDate                             50594 non-null  object
#  45  awards/0/contractPeriod/durationInDays                      38747 non-null  float64
#  46  awards/0/items/0/id                                         50744 non-null  object
#  47  awards/0/items/0/description                                50744 non-null  object
#  48  awards/0/items/0/classification/id                          50744 non-null  object
#  49  awards/0/items/0/quantity                                   50744 non-null  float64
#  50  awards/0/items/0/unit/name                                  50744 non-null  object
#  51  awards/0/items/0/unit/value/amount                          50744 non-null  float64
#  52  awards/0/items/0/unit/value/currency                        41869 non-null  object
#  53  awards/0/documents/0/id                                     50744 non-null  object
#  54  awards/0/documents/0/url                                    50744 non-null  object
#  55  awards/0/documents/0/datePublished                          50744 non-null  object
#  56  awards/0/suppliers/0/name                                   50744 non-null  object
#  57  awards/0/suppliers/0/id                                     50716 non-null  object
#  58  contracts/0/id                                              50744 non-null  object
#  59  contracts/0/awardID                                         50744 non-null  object
#  60  contracts/0/title                                           50744 non-null  object
#  61  contracts/0/description                                     50744 non-null  object
#  62  contracts/0/status                                          50744 non-null  object
#  63  contracts/0/period/startDate                                38926 non-null  object
#  64  contracts/0/period/endDate                                  50694 non-null  object
#  65  contracts/0/period/durationInDays                           38926 non-null  float64
#  66  contracts/0/value/amount                                    50744 non-null  float64
#  67  contracts/0/value/currency                                  42486 non-null  object
#  68  contracts/0/dateSigned                                      50744 non-null  object
#  69  contracts/0/items/0/id                                      50744 non-null  object
#  70  contracts/0/items/0/description                             50744 non-null  object
#  71  contracts/0/items/0/classification/id                       50744 non-null  object
#  72  contracts/0/items/0/quantity                                50744 non-null  float64
#  73  contracts/0/items/0/unit/name                               50744 non-null  object
#  74  contracts/0/items/0/unit/value/amount                       50744 non-null  float64
#  75  contracts/0/items/0/unit/value/currency                     50744 non-null  object
#  76  contracts/0/signatories/0/name                              50744 non-null  object
#  77  contracts/0/signatories/0/id                                50700 non-null  object
#  78  parties/0/name                                              54561 non-null  object
#  79  parties/0/id                                                54575 non-null  object
#  80  parties/0/identifier/scheme                                 55388 non-null  object
#  81  parties/0/identifier/id                                     54561 non-null  object
#  82  parties/0/identifier/legalName                              54561 non-null  object
#  83  parties/0/roles                                             55388 non-null  object
#  84  parties/0/contactPoint/telephone                            35107 non-null  float64
#  85  relatedProcesses/id                                         13140 non-null  float64
#  86  relatedProcesses/title                                      13140 non-null  object
#  87  relatedProcesses/identifier                                 11847 non-null  object
# dtypes: bool(2), float64(15), int64(2), object(69)
# memory usage: 36.9+ MB

# %%
active = df['tender/status'] == 'active'
active_df = df[active]
active_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4961 entries, 0 to 65308
# Data columns (total 88 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   date                                                        4961 non-null   object
#  1   tag                                                         4961 non-null   object
#  2   tender/id                                                   4961 non-null   object
#  3   tender/title                                                4961 non-null   object
#  4   tender/description                                          4961 non-null   object
#  5   tender/status                                               4961 non-null   object
#  6   tender/procuringEntity/id                                   4961 non-null   object
#  7   tender/value/currency                                       4961 non-null   object
#  8   tender/value/amount                                         4961 non-null   float64
#  9   tender/procuringEntity/name                                 4961 non-null   object
#  10  tender/procurementMethod                                    4961 non-null   object
#  11  tender/procurementMethodDetails                             4961 non-null   object
#  12  tender/mainProcurementCategory                              4961 non-null   object
#  13  tender/additionalProcurementCategories                      4961 non-null   object
#  14  tender/tenderPeriod/startDate                               4961 non-null   object
#  15  tender/tenderPeriod/endDate                                 4961 non-null   object
#  16  tender/tenderPeriod/durationInDays                          4961 non-null   int64
#  17  tender/enquiryPeriod/startDate                              4961 non-null   object
#  18  tender/enquiryPeriod/endDate                                4961 non-null   object
#  19  tender/enquiryPeriod/durationInDays                         4961 non-null   int64
#  20  tender/techniques/frameworkAgreement/period/startDate       0 non-null      object
#  21  tender/techniques/frameworkAgreement/period/endDate         0 non-null      object
#  22  tender/techniques/frameworkAgreement/period/durationInDays  0 non-null      float64
#  23  tender/techniques/frameworkAgreement/value/amount           0 non-null      float64
#  24  tender/techniques/frameworkAgreement/value/currency         0 non-null      object
#  25  tender/techniques/hasFrameworkAgreement                     4961 non-null   bool
#  26  tender/competitive                                          4961 non-null   bool
#  27  tender/items/0/id                                           4961 non-null   object
#  28  tender/items/0/description                                  4961 non-null   object
#  29  tender/items/0/quantity                                     4961 non-null   float64
#  30  tender/items/0/unit/name                                    4961 non-null   object
#  31  tender/items/0/classification/id                            4961 non-null   object
#  32  tender/items/0/unit/value/amount                            4961 non-null   float64
#  33  tender/items/0/unit/value/currency                          4961 non-null   object
#  34  tender/documents/0/id                                       4961 non-null   object
#  35  tender/documents/0/url                                      4961 non-null   object
#  36  tender/documents/0/datePublished                            4961 non-null   object
#  37  awards/0/id                                                 0 non-null      object
#  38  awards/0/title                                              0 non-null      object
#  39  awards/0/description                                        0 non-null      object
#  40  awards/0/date                                               0 non-null      object
#  41  awards/0/value/amount                                       0 non-null      float64
#  42  awards/0/value/currency                                     0 non-null      object
#  43  awards/0/contractPeriod/startDate                           0 non-null      object
#  44  awards/0/contractPeriod/endDate                             0 non-null      object
#  45  awards/0/contractPeriod/durationInDays                      0 non-null      float64
#  46  awards/0/items/0/id                                         0 non-null      object
#  47  awards/0/items/0/description                                0 non-null      object
#  48  awards/0/items/0/classification/id                          0 non-null      object
#  49  awards/0/items/0/quantity                                   0 non-null      float64
#  50  awards/0/items/0/unit/name                                  0 non-null      object
#  51  awards/0/items/0/unit/value/amount                          0 non-null      float64
#  52  awards/0/items/0/unit/value/currency                        0 non-null      object
#  53  awards/0/documents/0/id                                     0 non-null      object
#  54  awards/0/documents/0/url                                    0 non-null      object
#  55  awards/0/documents/0/datePublished                          0 non-null      object
#  56  awards/0/suppliers/0/name                                   0 non-null      object
#  57  awards/0/suppliers/0/id                                     0 non-null      object
#  58  contracts/0/id                                              0 non-null      object
#  59  contracts/0/awardID                                         0 non-null      object
#  60  contracts/0/title                                           0 non-null      object
#  61  contracts/0/description                                     0 non-null      object
#  62  contracts/0/status                                          0 non-null      object
#  63  contracts/0/period/startDate                                0 non-null      object
#  64  contracts/0/period/endDate                                  0 non-null      object
#  65  contracts/0/period/durationInDays                           0 non-null      float64
#  66  contracts/0/value/amount                                    0 non-null      float64
#  67  contracts/0/value/currency                                  0 non-null      object
#  68  contracts/0/dateSigned                                      0 non-null      object
#  69  contracts/0/items/0/id                                      0 non-null      object
#  70  contracts/0/items/0/description                             0 non-null      object
#  71  contracts/0/items/0/classification/id                       0 non-null      object
#  72  contracts/0/items/0/quantity                                0 non-null      float64
#  73  contracts/0/items/0/unit/name                               0 non-null      object
#  74  contracts/0/items/0/unit/value/amount                       0 non-null      float64
#  75  contracts/0/items/0/unit/value/currency                     0 non-null      object
#  76  contracts/0/signatories/0/name                              0 non-null      object
#  77  contracts/0/signatories/0/id                                0 non-null      object
#  78  parties/0/name                                              4961 non-null   object
#  79  parties/0/id                                                4961 non-null   object
#  80  parties/0/identifier/scheme                                 4961 non-null   object
#  81  parties/0/identifier/id                                     4961 non-null   object
#  82  parties/0/identifier/legalName                              4961 non-null   object
#  83  parties/0/roles                                             4961 non-null   object
#  84  parties/0/contactPoint/telephone                            4961 non-null   float64
#  85  relatedProcesses/id                                         1447 non-null   float64
#  86  relatedProcesses/title                                      1447 non-null   object
#  87  relatedProcesses/identifier                                 0 non-null      object
# dtypes: bool(2), float64(15), int64(2), object(69)
# memory usage: 3.3+ MB

# %%
complete_df.to_csv('complete.csv')
active_df.to_csv('active.csv')

# %%
# Dentro de las licitacion con status complete, nos interesan las filas de supliers, empresas que ganaron cada una 

complete_suplier = complete_df['parties/0/roles'] == 'supplier'
complete_suplier_df = complete_df[complete_suplier]
complete_suplier_df.info()
complete_suplier_df.to_csv('complete_suplier.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20281 entries, 29 to 65377
# Data columns (total 88 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   date                                                        20281 non-null  object
#  1   tag                                                         20281 non-null  object
#  2   tender/id                                                   20281 non-null  object
#  3   tender/title                                                20281 non-null  object
#  4   tender/description                                          20281 non-null  object
#  5   tender/status                                               20281 non-null  object
#  6   tender/procuringEntity/id                                   20281 non-null  object
#  7   tender/value/currency                                       20281 non-null  object
#  8   tender/value/amount                                         20281 non-null  float64
#  9   tender/procuringEntity/name                                 20253 non-null  object
#  10  tender/procurementMethod                                    20281 non-null  object
#  11  tender/procurementMethodDetails                             20281 non-null  object
#  12  tender/mainProcurementCategory                              20281 non-null  object
#  13  tender/additionalProcurementCategories                      20281 non-null  object
#  14  tender/tenderPeriod/startDate                               20281 non-null  object
#  15  tender/tenderPeriod/endDate                                 20281 non-null  object
#  16  tender/tenderPeriod/durationInDays                          20281 non-null  int64
#  17  tender/enquiryPeriod/startDate                              20281 non-null  object
#  18  tender/enquiryPeriod/endDate                                20281 non-null  object
#  19  tender/enquiryPeriod/durationInDays                         20281 non-null  int64
#  20  tender/techniques/frameworkAgreement/period/startDate       18 non-null     object
#  21  tender/techniques/frameworkAgreement/period/endDate         1414 non-null   object
#  22  tender/techniques/frameworkAgreement/period/durationInDays  18 non-null     float64
#  23  tender/techniques/frameworkAgreement/value/amount           1414 non-null   float64
#  24  tender/techniques/frameworkAgreement/value/currency         1414 non-null   object
#  25  tender/techniques/hasFrameworkAgreement                     20281 non-null  bool
#  26  tender/competitive                                          20281 non-null  bool
#  27  tender/items/0/id                                           20281 non-null  object
#  28  tender/items/0/description                                  20281 non-null  object
#  29  tender/items/0/quantity                                     20281 non-null  float64
#  30  tender/items/0/unit/name                                    20281 non-null  object
#  31  tender/items/0/classification/id                            20281 non-null  object
#  32  tender/items/0/unit/value/amount                            20281 non-null  float64
#  33  tender/items/0/unit/value/currency                          20281 non-null  object
#  34  tender/documents/0/id                                       20281 non-null  object
#  35  tender/documents/0/url                                      20281 non-null  object
#  36  tender/documents/0/datePublished                            20281 non-null  object
#  37  awards/0/id                                                 20281 non-null  object
#  38  awards/0/title                                              20281 non-null  object
#  39  awards/0/description                                        20281 non-null  object
#  40  awards/0/date                                               20281 non-null  object
#  41  awards/0/value/amount                                       20281 non-null  float64
#  42  awards/0/value/currency                                     15989 non-null  object
#  43  awards/0/contractPeriod/startDate                           18792 non-null  object
#  44  awards/0/contractPeriod/endDate                             20206 non-null  object
#  45  awards/0/contractPeriod/durationInDays                      18792 non-null  float64
#  46  awards/0/items/0/id                                         20281 non-null  object
#  47  awards/0/items/0/description                                20281 non-null  object
#  48  awards/0/items/0/classification/id                          20281 non-null  object
#  49  awards/0/items/0/quantity                                   20281 non-null  float64
#  50  awards/0/items/0/unit/name                                  20281 non-null  object
#  51  awards/0/items/0/unit/value/amount                          20281 non-null  float64
#  52  awards/0/items/0/unit/value/currency                        15989 non-null  object
#  53  awards/0/documents/0/id                                     20281 non-null  object
#  54  awards/0/documents/0/url                                    20281 non-null  object
#  55  awards/0/documents/0/datePublished                          20281 non-null  object
#  56  awards/0/suppliers/0/name                                   20281 non-null  object
#  57  awards/0/suppliers/0/id                                     20267 non-null  object
#  58  contracts/0/id                                              20281 non-null  object
#  59  contracts/0/awardID                                         20281 non-null  object
#  60  contracts/0/title                                           20281 non-null  object
#  61  contracts/0/description                                     20281 non-null  object
#  62  contracts/0/status                                          20281 non-null  object
#  63  contracts/0/period/startDate                                18860 non-null  object
#  64  contracts/0/period/endDate                                  20256 non-null  object
#  65  contracts/0/period/durationInDays                           18860 non-null  float64
#  66  contracts/0/value/amount                                    20281 non-null  float64
#  67  contracts/0/value/currency                                  16292 non-null  object
#  68  contracts/0/dateSigned                                      20281 non-null  object
#  69  contracts/0/items/0/id                                      20281 non-null  object
#  70  contracts/0/items/0/description                             20281 non-null  object
#  71  contracts/0/items/0/classification/id                       20281 non-null  object
#  72  contracts/0/items/0/quantity                                20281 non-null  float64
#  73  contracts/0/items/0/unit/name                               20281 non-null  object
#  74  contracts/0/items/0/unit/value/amount                       20281 non-null  float64
#  75  contracts/0/items/0/unit/value/currency                     20281 non-null  object
#  76  contracts/0/signatories/0/name                              20281 non-null  object
#  77  contracts/0/signatories/0/id                                20260 non-null  object
#  78  parties/0/name                                              20281 non-null  object
#  79  parties/0/id                                                20281 non-null  object
#  80  parties/0/identifier/scheme                                 20281 non-null  object
#  81  parties/0/identifier/id                                     20267 non-null  object
#  82  parties/0/identifier/legalName                              20281 non-null  object
#  83  parties/0/roles                                             20281 non-null  object
#  84  parties/0/contactPoint/telephone                            0 non-null      float64
#  85  relatedProcesses/id                                         1414 non-null   float64
#  86  relatedProcesses/title                                      1414 non-null   object
#  87  relatedProcesses/identifier                                 1414 non-null   object
# dtypes: bool(2), float64(15), int64(2), object(69)
# memory usage: 13.5+ MB

# %%
# Analizo las divisas

ocurrencia = complete_suplier_df.pivot_table(index = ['tender/value/currency'], aggfunc ='size')
print(ocurrencia)
# Out:
# tender/value/currency
# ARS    20157
# EUR        2
# USD      122
# dtype: int64

# %%
# monto total en cada divisa

def totalmonto(divisa):
    aux = complete_suplier_df['tender/value/currency'] == divisa
    complete_suplier_ARG_df = complete_suplier_df[aux]
    print(complete_suplier_ARG_df['tender/value/amount'].sum())
    
    return 

print("Monto total en PESOS: ")
totalmonto('ARS')
print("\nMonto total en USD: ")
totalmonto('USD')
print("\nMonto total en EUR: ")
totalmonto('EUR')
# ARS = complete_suplier_df['tender/value/currency'] == 'ARS'
# complete_suplier_ARG_df = complete_suplier_df[ARS]
# complete_suplier_ARG_df['tender/value/amount'].sum()
# complete_suplier_df.info()
# complete_suplier_df.to_csv('complete_suplier.csv')
# Out:
# Monto total en PESOS:
# 933614053858.1204
#
# Monto total en USD:
# 1301660265.97
#
# Monto total en EUR:
# 10649319.3
